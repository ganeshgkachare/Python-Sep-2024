# %%
import pandas as pd

# %%
#Q1: Read data from sheet "Data"

# %%
pd.read_excel(r'C:\Ganesh\Minskole Python Batch\Homework.xlsx',sheet_name="Data")
# Out:
#    Unnamed: 0  Unnamed: 1   Unnamed: 2 Unnamed: 3 Unnamed: 4   Unnamed: 5  \
# 0         NaN         NaN          NaN        NaN        NaN          NaN
# 1         NaN         NaN          NaN        NaN        NaN          NaN
# 2     Roll No  First Name    Last Name    English   Physics    Chemistry
# 3           1       Aarav        Patil         85         78           90
# 4           2       Aarvi     Bhandari         90         81           85
# 5           3       Aditi       Rajput         90         88           82
# 6           4      Aditya        Pawar         92         88           76
# 7           5       Anaya      Gawande         84         90           82
# 8           6       Arjun         More         76         89           91
# 9           7       Arnav      Khedkar         85         90           78
# 10          8       Ayaan       Jadhav         90         75           88
# 11          9       Disha       Chavan         86         83           80
# ...

# %%
Data=pd.read_excel(r'C:\Ganesh\Minskole Python Batch\Homework.xlsx',sheet_name="Data",header=3)

# %%
Data.head()
# Out:
#    Roll No First Name Last Name  English  Physics    Chemistry   Mathematics  \
# 0        1      Aarav     Patil       85        78           90           92
# 1        2      Aarvi  Bhandari       90        81           85           91
# 2        3      Aditi    Rajput       90        88           82           87
# 3        4     Aditya     Pawar       92        88           76           91
# 4        5      Anaya   Gawande       84        90           82           88
#
#    DOB Year
# 0      1998
# 1      2001
# 2      2000
# 3      1999
# 4      1997

# %%
#Q2: Find out student age

# %%
Data["Student_age"]=2024-Data["DOB Year"]

# %%
Data.head()
# Out:
#    Roll No First Name Last Name  English  Physics    Chemistry   Mathematics  \
# 0        1      Aarav     Patil       85        78           90           92
# 1        2      Aarvi  Bhandari       90        81           85           91
# 2        3      Aditi    Rajput       90        88           82           87
# 3        4     Aditya     Pawar       92        88           76           91
# 4        5      Anaya   Gawande       84        90           82           88
#
#    DOB Year  Student_age
# 0      1998           26
# 1      2001           23
# 2      2000           24
# 3      1999           25
# 4      1997           27

# %%
#Q3: Calculate total marks

# %%
"Physics" in Data.columns
# Out:
# False

# %%
"Physics " in Data.columns
# Out:
# True

# %%
Data["Total Marks"]=Data["English"]+Data["Physics"]+Data["Chemistry"]+Data["Mathematics"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Physics'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
Data.columns
# Out:
# Index(['Roll No', 'First Name', 'Last Name', 'English', 'Physics ',
#        ' Chemistry ', 'Mathematics', 'DOB Year', 'Student_age'],
#       dtype='object')

# %%
Data["Total Marks"]=Data["English"]+Data["Physics "]+Data[" Chemistry "]+Data["Mathematics"]

# %%
Data
# Out:
#     Roll No First Name    Last Name  English  Physics    Chemistry   \
# 0         1      Aarav        Patil       85        78           90
# 1         2      Aarvi     Bhandari       90        81           85
# 2         3      Aditi       Rajput       90        88           82
# 3         4     Aditya        Pawar       92        88           76
# 4         5      Anaya      Gawande       84        90           82
# 5         6      Arjun         More       76        89           91
# 6         7      Arnav      Khedkar       85        90           78
# 7         8      Ayaan       Jadhav       90        75           88
# 8         9      Disha       Chavan       86        83           80
# 9        10       Isha       Kamble       79        76           89
# 10       11       Jaya       Bhagat       92        88           76
# 11       12        Jay       Bhagat       90        77           65
# 12       13      Kaira        Nikam       88        80           84
# ...

# %%
#Q4: Calculate percentage

# %%
Data["Percentage"]=(Data["Total Marks"]/400)*100

# %%
Data
# Out:
#     Roll No First Name    Last Name  English  Physics    Chemistry   \
# 0         1      Aarav        Patil       85        78           90
# 1         2      Aarvi     Bhandari       90        81           85
# 2         3      Aditi       Rajput       90        88           82
# 3         4     Aditya        Pawar       92        88           76
# 4         5      Anaya      Gawande       84        90           82
# 5         6      Arjun         More       76        89           91
# 6         7      Arnav      Khedkar       85        90           78
# 7         8      Ayaan       Jadhav       90        75           88
# 8         9      Disha       Chavan       86        83           80
# 9        10       Isha       Kamble       79        76           89
# 10       11       Jaya       Bhagat       92        88           76
# 11       12        Jay       Bhagat       90        77           65
# 12       13      Kaira        Nikam       88        80           84
# ...

# %%
#Q5: Give top 10 student Roll No, first name, last name, Total marks

# %%
Top_10_Stu=Data.sort_values(by="Total Marks",ascending=False)

# %%
Top_10_Stu.columns
# Out:
# Index(['Roll No', 'First Name', 'Last Name', 'English', 'Physics ',
#        ' Chemistry ', 'Mathematics', 'DOB Year', 'Student_age', 'Total Marks',
#        'Percentage'],
#       dtype='object')

# %%
Top_10_Stu
# Out:
#     Roll No First Name    Last Name  English  Physics    Chemistry   \
# 27       28      Sneha      Gokhale       88        84           90
# 2         3      Aditi       Rajput       90        88           82
# 3         4     Aditya        Pawar       92        88           76
# 1         2      Aarvi     Bhandari       90        81           85
# 0         1      Aarav        Patil       85        78           90
# 10       11       Jaya       Bhagat       92        88           76
# 4         5      Anaya      Gawande       84        90           82
# 31       32     Vihaan     Deshmukh       88        81           85
# 17       18      Pooja       Mhatre       84        79           88
# 16       17      Payal        Patil       89        76           87
# 12       13      Kaira        Nikam       88        80           84
# 30       31      Tejas     Waghmare       85        82           90
# 26       27     Shreya     Dandekar       89        75           88
# ...

# %%
# Top_10_Stu[["Roll No","First Name","Last Name","Total Marks"]]
# Top_10_Stu.iloc[row,column]

# %%
# M1
Top_10_Stu.iloc[0:10,[0,1,2,8]]
# Out:
#     Roll No First Name Last Name  Student_age
# 27       28      Sneha   Gokhale           22
# 2         3      Aditi    Rajput           24
# 3         4     Aditya     Pawar           25
# 1         2      Aarvi  Bhandari           23
# 0         1      Aarav     Patil           26
# 10       11       Jaya    Bhagat           28
# 4         5      Anaya   Gawande           27
# 31       32     Vihaan  Deshmukh           23
# 17       18      Pooja    Mhatre           23
# 16       17      Payal     Patil           25

# %%
# M2)
Top_10_Stu=Top_10_Stu[["Roll No","First Name","Last Name","Total Marks"]].iloc[0:10]

# %%
Top_10_Stu
# Out:
#     Roll No First Name Last Name  Total Marks
# 27       28      Sneha   Gokhale          348
# 2         3      Aditi    Rajput          347
# 3         4     Aditya     Pawar          347
# 1         2      Aarvi  Bhandari          347
# 0         1      Aarav     Patil          345
# 10       11       Jaya    Bhagat          345
# 4         5      Anaya   Gawande          344
# 31       32     Vihaan  Deshmukh          343
# 17       18      Pooja    Mhatre          343
# 16       17      Payal     Patil          343

# %%
#Q6: In above data add first name and last name in single column

# %%
Data["Full Name"]=Data["First Name"]+" "+Data["Last Name"]

# %%
Top_10_Stu["Full Name"]=Top_10_Stu["First Name"]+" "+Top_10_Stu["Last Name"]

# %%
Top_10_Stu
# Out:
#     Roll No First Name Last Name  Total Marks        Full Name
# 27       28      Sneha   Gokhale          348    Sneha Gokhale
# 2         3      Aditi    Rajput          347     Aditi Rajput
# 3         4     Aditya     Pawar          347     Aditya Pawar
# 1         2      Aarvi  Bhandari          347   Aarvi Bhandari
# 0         1      Aarav     Patil          345      Aarav Patil
# 10       11       Jaya    Bhagat          345      Jaya Bhagat
# 4         5      Anaya   Gawande          344    Anaya Gawande
# 31       32     Vihaan  Deshmukh          343  Vihaan Deshmukh
# 17       18      Pooja    Mhatre          343     Pooja Mhatre
# 16       17      Payal     Patil          343      Payal Patil

# %%
#Q7: Give list of student whoes marks less than 50 in any subject

# %%
Data[(Data['English']<50) | (Data['Physics ']<50) | (Data[' Chemistry ']<50) | (Data['Mathematics']<50) ]
# Out:
#     Roll No First Name Last Name  English  Physics    Chemistry   Mathematics  \
# 6         7      Arnav   Khedkar       85        90           78           46
# 19       20     Raghav  Khedekar       79        49           82           90
# 25       26    Samarth    Shinde       43        79           87           88
# 29       30      Tarun    Dhumal       82        87           44           85
#
#     DOB Year  Student_age  Total Marks  Percentage
# 6       2000           24          299       74.75
# 19      1996           28          300       75.00
# 25      2000           24          297       74.25
# 29      2000           24          298       74.50

# %%
# Data[(Data['English']<50) & (Data['Physics ']<50) & (Data[' Chemistry ']<50) & (Data['Mathematics']<50) ]
# Out:
# Empty DataFrame
# Columns: [Roll No, First Name, Last Name, English, Physics ,  Chemistry , Mathematics, DOB Year, Student_age, Total Marks, Percentage]
# Index: []

# %%
# Or
# True or False ==>True
# False or False ==>False
# True or True ==>True
# False or True ==>True

# %%
Data
# Out:
#     Roll No First Name    Last Name  English  Physics    Chemistry   \
# 0         1      Aarav        Patil       85        78           90
# 1         2      Aarvi     Bhandari       90        81           85
# 2         3      Aditi       Rajput       90        88           82
# 3         4     Aditya        Pawar       92        88           76
# 4         5      Anaya      Gawande       84        90           82
# 5         6      Arjun         More       76        89           91
# 6         7      Arnav      Khedkar       85        90           78
# 7         8      Ayaan       Jadhav       90        75           88
# 8         9      Disha       Chavan       86        83           80
# 9        10       Isha       Kamble       79        76           89
# 10       11       Jaya       Bhagat       92        88           76
# 11       12        Jay       Bhagat       90        77           65
# 12       13      Kaira        Nikam       88        80           84
# ...

# %%
# Export data to excel/csv
#1) Excel file: 
#               DataFrame_name.to_excel(r"path/filename.xlsx",index=False/True)
#2) CSV file: 
#               DataFrame_name.to_csv(r"path/filename.csv",index=False/True)

# %%
Data.to_excel(r"C:\Ganesh\Minskole Python Batch\Output\R1.xlsx")

# %%
Data.to_excel(r"C:\Ganesh\Minskole Python Batch\Output\R2.xlsx",index=False) #Index excluded

# %%
Data.to_csv(r"C:\Ganesh\Minskole Python Batch\Output\R2_csv.csv",index=False) #Index excluded
