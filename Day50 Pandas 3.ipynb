# %%
import pandas as pd

# %%
# Read excel file in pandas
# Syntax
# pd.read_excel("file_path/file_name.xlsx") ==> Excel
# pd.read_csv("file_path/file_name.csv")  ==> csv

# %%
# path
# extensions ==> .xlsx = excel file  
                 # .csv= csv file
# single / double slash / raw string

# sheet_name : Specifies which sheet in the Excel file to read. By default read first sheet
# header (None/other number) : Define which row to use as the header (column names).
# usecols : Define which columns to read from the Excel sheet.
# skiprows : Skips a specified number of rows at the start ==> int ==> # starting recods removed
#                                                          ==> []  ==> Defined rows removed

# %%
pd.read_excel(r"C:\Ganesh\Minskole Python Batch\tResult1.xlsx")
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1   student1    34    40    50    32   Fail                 37.0
# 1        2   student2    45    22    67    55   Fail                 33.5
# 2        3   student3    67    32    44    34   Fail                 49.5
# 3        4   student4    38    42    27    34   Fail                 40.0
# 4        5   student5    56    50    67    44   Pass                 53.0
# 5        6   student6    76    67    56    44   Pass                 71.5
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5
# ...

# %%
pd.read_excel(r"C:\Ganesh\Minskole Python Batch\tResult1.xlsx",sheet_name="S2")
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4
# 0        1   student1    34    40    50    32
# 1        2   student2    45    22    67    55
# 2        3   student3    67    32    44    34
# 3        4   student4    38    42    27    34
# 4        5   student5    56    50    67    44
# 5        6   student6    76    67    56    44
# 6        7   student7    66    44    76    38
# 7        8   student8    45    27    55    56
# 8        9   student9    66    44    45    55
# 9       10  student10    73    55    66    88

# %%
pd.read_excel(r"C:\Ganesh\Minskole Python Batch\tResult1.xlsx",sheet_name="S2",header=None) # header=None==> all data consider as record
# Out:
#           0          1     2     3     4     5
# 0   Exam No    Student  Sem1  Sem2  Sem3  Sem4
# 1         1   student1    34    40    50    32
# 2         2   student2    45    22    67    55
# 3         3   student3    67    32    44    34
# 4         4   student4    38    42    27    34
# 5         5   student5    56    50    67    44
# 6         6   student6    76    67    56    44
# 7         7   student7    66    44    76    38
# 8         8   student8    45    27    55    56
# 9         9   student9    66    44    45    55
# 10       10  student10    73    55    66    88

# %%
pd.read_excel(r"C:\Ganesh\Minskole Python Batch\tResult1.xlsx",sheet_name="S2",header=5)
# Out:
#     5   student5  56  50  67  44
# 0   6   student6  76  67  56  44
# 1   7   student7  66  44  76  38
# 2   8   student8  45  27  55  56
# 3   9   student9  66  44  45  55
# 4  10  student10  73  55  66  88

# %%
pd.read_excel(r"C:\Ganesh\Minskole Python Batch\tResult1.xlsx",sheet_name="S3",header=4)
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4
# 0        1   student1    34    40    50    32
# 1        2   student2    45    22    67    55
# 2        3   student3    67    32    44    34
# 3        4   student4    38    42    27    34
# 4        5   student5    56    50    67    44
# 5        6   student6    76    67    56    44
# 6        7   student7    66    44    76    38
# 7        8   student8    45    27    55    56
# 8        9   student9    66    44    45    55
# 9       10  student10    73    55    66    88

# %%
pd.read_excel(r"C:\Ganesh\Minskole Python Batch\tResult1.xlsx",sheet_name="S22")
# Out:
#     Exam No    Student  Sem1  Sem2  Sem3  Sem4
# 0       1.0   student1  34.0  40.0  50.0  32.0
# 1       2.0   student2  45.0  22.0  67.0  55.0
# 2       3.0   student3  67.0  32.0  44.0  34.0
# 3       NaN        NaN   NaN   NaN   NaN   NaN
# 4       NaN        NaN   NaN   NaN   NaN   NaN
# 5       4.0   student4  38.0  42.0  27.0  34.0
# 6       5.0   student5  56.0  50.0  67.0  44.0
# 7       6.0   student6  76.0  67.0  56.0  44.0
# 8       7.0   student7  66.0  44.0  76.0  38.0
# 9       8.0   student8  45.0  27.0  55.0  56.0
# 10      9.0   student9  66.0  44.0  45.0  55.0
# 11     10.0  student10  73.0  55.0  66.0  88.0

# %%
pd.read_excel(r"C:\Ganesh\Minskole Python Batch\tResult1.xlsx",sheet_name="S22",skiprows=4)
# Out:
#    Unnamed: 0 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5
# 0         NaN        NaN         NaN         NaN         NaN         NaN
# 1         4.0   student4        38.0        42.0        27.0        34.0
# 2         5.0   student5        56.0        50.0        67.0        44.0
# 3         6.0   student6        76.0        67.0        56.0        44.0
# 4         7.0   student7        66.0        44.0        76.0        38.0
# 5         8.0   student8        45.0        27.0        55.0        56.0
# 6         9.0   student9        66.0        44.0        45.0        55.0
# 7        10.0  student10        73.0        55.0        66.0        88.0

# %%
pd.read_excel(r"C:\Ganesh\Minskole Python Batch\tResult1.xlsx",sheet_name="S22",skiprows=[4,5])
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4
# 0        1   student1    34    40    50    32
# 1        2   student2    45    22    67    55
# 2        3   student3    67    32    44    34
# 3        4   student4    38    42    27    34
# 4        5   student5    56    50    67    44
# 5        6   student6    76    67    56    44
# 6        7   student7    66    44    76    38
# 7        8   student8    45    27    55    56
# 8        9   student9    66    44    45    55
# 9       10  student10    73    55    66    88

# %%
pd.read_excel(r"C:\Ganesh\Minskole Python Batch\tResult1.xlsx",sheet_name="S3",skiprows=[0,1,2,3,4,5])

# %%
pd.read_excel(r"C:\Ganesh\Minskole Python Batch\Result1.xlsx",usecols=["Exam No","Student","Result"])
# Out:
#    Exam No    Student Result
# 0        1   student1   Fail
# 1        2   student2   Fail
# 2        3   student3   Fail
# 3        4   student4   Fail
# 4        5   student5   Pass
# 5        6   student6   Pass
# 6        7   student7   Pass
# 7        8   student8   Fail
# 8        9   student9   Pass
# 9       10  student10   Pass

# %%
# Read csv file in pandas

# %%
pd.read_csv(r"C:\Ganesh\Minskole Python Batch\Resultcsv.csv")

# %%
pd.read_csv(r"C:\Ganesh\Minskole Python Batch\Resultcsv.csv",delimiter=",")
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1   student1    34    40    50    32   Fail                 37.0
# 1        2   student2    45    22    67    55   Fail                 33.5
# 2        3   student3    67    32    44    34   Fail                 49.5
# 3        4   student4    38    42    27    34   Fail                 40.0
# 4        5   student5    56    50    67    44   Pass                 53.0
# 5        6   student6    76    67    56    44   Pass                 71.5
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5
# ...

# %%
data=pd.read_excel(r"C:\Ganesh\Minskole Python Batch\Result1.xlsx")

# %%
data
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1   student1    34    40    50    32   Fail                 37.0
# 1        2   student2    45    22    67    55   Fail                 33.5
# 2        3   student3    67    32    44    34   Fail                 49.5
# 3        4   student4    38    42    27    34   Fail                 40.0
# 4        5   student5    56    50    67    44   Pass                 53.0
# 5        6   student6    76    67    56    44   Pass                 71.5
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()  # Show starting 5 rows / #rows you mentioned in Parentheses
# Out:
#    Exam No   Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1  student1    34    40    50    32   Fail                 37.0
# 1        2  student2    45    22    67    55   Fail                 33.5
# 2        3  student3    67    32    44    34   Fail                 49.5
# 3        4  student4    38    42    27    34   Fail                 40.0
# 4        5  student5    56    50    67    44   Pass                 53.0
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5

# %%
data.head(2)  # Show starting 5 rows / #rows you mentioned in Parentheses
# Out:
#    Exam No   Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1  student1    34    40    50    32   Fail                 37.0
# 1        2  student2    45    22    67    55   Fail                 33.5
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0

# %%
data.tail(3)  # Show last 5 rows / #rows you mentioned in Parentheses
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 7                 55.5
# 8                 50.0
# 9                 77.0

# %%
data.tail()  # Show last 5 rows / #rows you mentioned in Parentheses
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 5        6   student6    76    67    56    44   Pass                 71.5
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 5                 50.0
# 6                 57.0
# 7                 55.5
# 8                 50.0
# 9                 77.0

# %%
data
# Out:
#    Exam No    Student  Sem1  Sem2  Sem3  Sem4 Result  1st Year percentage  \
# 0        1   student1    34    40    50    32   Fail                 37.0
# 1        2   student2    45    22    67    55   Fail                 33.5
# 2        3   student3    67    32    44    34   Fail                 49.5
# 3        4   student4    38    42    27    34   Fail                 40.0
# 4        5   student5    56    50    67    44   Pass                 53.0
# 5        6   student6    76    67    56    44   Pass                 71.5
# 6        7   student7    66    44    76    38   Pass                 55.0
# 7        8   student8    45    27    55    56   Fail                 36.0
# 8        9   student9    66    44    45    55   Pass                 55.0
# 9       10  student10    73    55    66    88   Pass                 64.0
#
#    2nd Year percentage
# 0                 41.0
# 1                 61.0
# 2                 39.0
# 3                 30.5
# 4                 55.5
# ...

# %%
# shape: Returns dimension of the DataFrame in tuple format (rows, columns).
data.shape
# Out:
# (10, 9)

# %%
# Returns dimension 
data.ndim
# Out:
# 2

# %%
# dtypes: Returns the data types of each column in the DataFrame.
data.dtypes
# Out:
# Exam No                  int64
# Student                 object
# Sem1                     int64
# Sem2                     int64
# Sem3                     int64
# Sem4                     int64
# Result                  object
# 1st Year percentage    float64
# 2nd Year percentage    float64
# dtype: object
