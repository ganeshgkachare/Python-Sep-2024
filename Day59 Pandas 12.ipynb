# %%
import pandas as pd

# %% [raw]
# concat: Used to combine data from different excel sheet without comparing any column value
#
# Concatenates two or more dataframes vertically or horizontally, based on the axis parameter.
# Does not consider the values of the columns of the dataframes being concatenated.
# Can be used to add rows or columns to a dataframe.
# The resulting dataframe will have the same columns as the original dataframes being concatenated.

# %%
#  Concatenation
df1 = pd.DataFrame(
    {
        "A": ["A0", "A1", "A2", "A3"],
        "B": ["B0", "B1", "B2", "B3"],
        "C": ["C0", "C1", "C2", "C3"],
        "D": ["D0", "D1", "D2", "D3"],
    },
    index=[0, 1, 2, 3],
)

# %%
df2 = pd.DataFrame(
    {
        "A": ["A4", "A5", "A6", "A7"],
        "B": ["B4", "B5", "B6", "B7"],
        "C": ["C4", "C5", "C6", "C7"],
        "D": ["D4", "D5", "D6", "D7"],
    },
    index=[4, 5, 6, 7],
)

# %%
df3 = pd.DataFrame(
    {
        "A": ["A8", "A9", "A10", "A11"],
        "B": ["B8", "B9", "B10", "B11"],
        "C": ["C8", "C9", "C10", "C11"],
        "D": ["D8", "D9", "D10", "D11"],
    },
    index=[4, 5, 6, 7],
)

# %%
df1
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
df3
# Out:
#      A    B    C    D
# 4   A8   B8   C8   D8
# 5   A9   B9   C9   D9
# 6  A10  B10  C10  D10
# 7  A11  B11  C11  D11

# %%
# pd.concat([df1,df2,df3],axis=0) # default is axis=0 # row
pd.concat([df1,df2,df3])
# Out:
#      A    B    C    D
# 0   A0   B0   C0   D0
# 1   A1   B1   C1   D1
# 2   A2   B2   C2   D2
# 3   A3   B3   C3   D3
# 4   A4   B4   C4   D4
# 5   A5   B5   C5   D5
# 6   A6   B6   C6   D6
# 7   A7   B7   C7   D7
# 4   A8   B8   C8   D8
# 5   A9   B9   C9   D9
# 6  A10  B10  C10  D10
# 7  A11  B11  C11  D11

# %%
pd.concat([df1,df2,df3],axis=1) # changing default is axis=0 to 1
# Out:
#      A    B    C    D    A    B    C    D    A    B    C    D
# 0   A0   B0   C0   D0  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2   A2   B2   C2   D2  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3   A3   B3   C3   D3  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN   A4   B4   C4   D4   A8   B8   C8   D8
# 5  NaN  NaN  NaN  NaN   A5   B5   C5   D5   A9   B9   C9   D9
# 6  NaN  NaN  NaN  NaN   A6   B6   C6   D6  A10  B10  C10  D10
# 7  NaN  NaN  NaN  NaN   A7   B7   C7   D7  A11  B11  C11  D11

# %%
pd.concat([df1,df2],axis=0)
# Out:
#     A   B   C   D
# 0  A0  B0  C0  D0
# 1  A1  B1  C1  D1
# 2  A2  B2  C2  D2
# 3  A3  B3  C3  D3
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
pd.concat([df1,df2],axis=1)
# Out:
#      A    B    C    D    A    B    C    D
# 0   A0   B0   C0   D0  NaN  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN  NaN
# 2   A2   B2   C2   D2  NaN  NaN  NaN  NaN
# 3   A3   B3   C3   D3  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN   A4   B4   C4   D4
# 5  NaN  NaN  NaN  NaN   A5   B5   C5   D5
# 6  NaN  NaN  NaN  NaN   A6   B6   C6   D6
# 7  NaN  NaN  NaN  NaN   A7   B7   C7   D7

# %% [raw]
# merge:
#
# Merges two or more dataframes based on one or more common columns.
# Can be used to combine data based on inner, outer, left, or right joins.
# Can handle non-matching values in the columns being merged.
# Can handle multiple columns being merged at once.
# The resulting dataframe may have new columns and rows depending on how the merge is performed.

# %%
# Syntax
pd.merge( left_df, right_df, on=[Both dataframe common column name]
                            on==> If column name same
                                  If column name different ==> left_on and right_on
                                                              left on=  [col1, col2]   = ["First name","Last Name"]
                                                            right on=  [col1, col2]    = ["First ","Last "]

# %%
Catalog=pd.read_excel(r"C:\Ganesh\Minskole Python Batch\Homework.xlsx",sheet_name="Catalog")

# %%
Eng=pd.read_excel(r"C:\Ganesh\Minskole Python Batch\Homework.xlsx",sheet_name="Eng")

# %%
Phy=pd.read_excel(r"C:\Ganesh\Minskole Python Batch\Homework.xlsx",sheet_name="Phy")

# %%
Merge=pd.merge(Catalog,Eng,on="Roll No") # In both dataframe column name is same and we need to merge data according to only one column

# %%
Merge.head()
# Out:
#    Roll No First Name Last Name  English
# 0        1      Aarav     Patil       85
# 1        2      Aarvi  Bhandari       90
# 2        3      Aditi    Rajput       90
# 3        4     Aditya     Pawar       92
# 4        5      Anaya   Gawande       84

# %%
Phy.head()
# Out:
#    Stud ID  Physics
# 0        1       78
# 1        2       81
# 2        3       88
# 3        4       88
# 4        5       90

# %%
Merge2=pd.merge(Merge    ,     Phy,   left_on="Roll No" ,                  right_on="Stud ID")
#               left df    right df     left df column need to consider   right df column need to consider
# Need to combine data according to single colum but column name is different

# %%
# Merge2=pd.merge(Merge    ,     Phy,   left_on=[col1,col2],                  right_on=[col3,col4])

# %%
Merge2
# Out:
#     Roll No First Name    Last Name  English  Stud ID  Physics
# 0         1      Aarav        Patil       85        1       78
# 1         2      Aarvi     Bhandari       90        2       81
# 2         3      Aditi       Rajput       90        3       88
# 3         4     Aditya        Pawar       92        4       88
# 4         5      Anaya      Gawande       84        5       90
# 5         6      Arjun         More       76        6       89
# 6         7      Arnav      Khedkar       85        7       90
# 7         8      Ayaan       Jadhav       90        8       75
# 8         9      Disha       Chavan       86        9       83
# 9        10       Isha       Kamble       79       10       76
# 10       11       Jaya       Bhagat       92       11       88
# 11       12        Jay       Bhagat       90       12       77
# 12       13      Kaira        Nikam       88       13       80
# 13       14      Krish      Bhosale       80       14       85
# ...

# %%
Catalog.head()
# Out:
#    Roll No First Name Last Name
# 0        1      Aarav     Patil
# 1        2      Aarvi  Bhandari
# 2        3      Aditi    Rajput
# 3        4     Aditya     Pawar
# 4        5      Anaya   Gawande

# %%
Eng.head()
# Out:
#    Roll No  English
# 0        4       92
# 1       11       92
# 2       23       92
# 3       24       91
# 4        2       90

# %%
data=pd.merge(Catalog,Eng,on="Roll No")

# %%
data

# %%
Concat_data_row=pd.concat([Catalog,Eng]) # Not correct

# %%
# Concat_data_row.to_excel(r"C:\Ganesh\Minskole Python Batch\Output\Concat R1.xlsx",index=False)

# %%
Concat_data_row2=pd.concat([Catalog,Eng],axis=1)

# %%
Concat_data_row2.to_excel(r"C:\Ganesh\Minskole Python Batch\Output\Concat R2.xlsx",index=False)

# %%
Merge.to_excel(r"C:\Ganesh\Minskole Python Batch\Output\Merge.xlsx",index=False)

# %%
Merge.to_excel(r"C:\Ganesh\Minskole Python Batch\Output\Merge2.xlsx")

# %%
Merge2.to_excel(r"C:\Ganesh\Minskole Python Batch\Output\Merge2.xlsx")
