# %%
import pandas as pd

# %%
# # Rename 
# # Syntax
# 1)Row labelled
#  dataframe_name.rename(index         = {1:"One",               4:"Four"} , inplace= True/False)
#                        For Row         Old value : New value,

# 2)Columns labelled
#  dataframe_name.rename(columns         = {1:"One",               4:"Four"} , inplace= True/False)
#                        For Column         Old value : New value,

# %%
data2=pd.read_excel(r"C:\Ganesh\Minskole Python Batch\input data.xlsx")

# %%
data2
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
# [65 rows x 6 columns]

# %%
# # Drop # Syntax
# # 1) Drop record (row)
# dataframe_name.drop([row_index], inplace= True/False) # By default axis=0

# # 2) Drop column
# dataframe_name.drop([column_name], axis=1, inplace= True/False)

# %%
data2
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 4     Reyansh     Joshi       82       80         84           85
# 5      Vivaan      Nair       87       83         79           90
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
# [64 rows x 6 columns]

# %%
data2.drop(3,inplace=True)

# %%
data2.drop([1,4,5],inplace=True)

# %%
data2["Full Name"]=data2["First Name"] + " " +data2["Last Name"]

# %%
data2.drop(["First Name","Last Name"],axis=1,inplace=True)

# %%
data2.rename(columns={"English":"Eng","Physics":"Phy"},inplace=True)

# %%
data2.head()
# Out:
#    Eng  Phy  Chemistry  Mathematics          Full Name
# 0   85   78         90           92        Aarav Patil
# 2   90   75         88           84       Ayaan Jadhav
# 6   92   88         76           91       Aditya Pawar
# 7   78   82         90           86  Rohan Suryavanshi
# 8   80   85         83           89      Krish Bhosale

# %%
data2.columns
# Out:
# Index(['Eng', 'Phy', 'Chemistry', 'Mathematics', 'Full Name'], dtype='object')

# %%
data2=data2[[ 'Full Name','Phy', 'Chemistry', 'Mathematics']] # Change sequence

# %%
data2
# Out:
#             Full Name  Phy  Chemistry  Mathematics
# 0         Aarav Patil   78         90           92
# 2        Ayaan Jadhav   75         88           84
# 6        Aditya Pawar   88         76           91
# 7   Rohan Suryavanshi   82         90           86
# 8       Krish Bhosale   85         83           89
# ..                ...  ...        ...          ...
# 60       Tarun Dhumal   87         81           85
# 61      Arnav Khedkar   90         78           89
# 62        Payal Patil   76         87           91
# 63        Rahul Kadam   83         84           90
# 64         Jay Bhagat   77         65           88
#
# [61 rows x 4 columns]

# %%
# data2.drop(["Maths","Eng"],axis=1)

# %%
"5"+5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4132\610440625.py in <module>
# ----> 1 "5"+5
#
# TypeError: can only concatenate str (not "int") to str

# %%
int("5")+5
# Out:
# 10

# %%
"5"+"5"
# Out:
# '55'

# %%
# Change column datatype /Typecasting
# Syntax
# dataframe/column.astype(new_datatype)

# %%
data3=pd.read_excel(r"C:\Ganesh\Minskole Python Batch\Datatype.xlsx")

# %%
data3=data3.astype(str)

# %%
data3["Total Marks"]= data3["English"]+data3["Physics"]+data3["Chemistry"]+data3["Mathematics"]

# %%
data3
# Out:
#   First Name    Last Name English Physics Chemistry Mathematics Total Marks
# 0      Aarav        Patil      85      78        90          92    85789092
# 1     Vihaan     Deshmukh      88      81        85          89    88818589
# 2      Ayaan       Jadhav      90      75        88          84    90758884
# 3      Arjun         More      76      89        91          78    76899178
# 4    Reyansh        Joshi      82      80        84          85    82808485
# 5     Vivaan         Nair      87      83        79          90    87837990
# 6     Aditya        Pawar      92      88        76          91    92887691
# 7      Rohan  Suryavanshi      78      82        90          86    78829086

# %%
data3["Physics"]=data3["Physics"].astype(int)

# %%
data3["Total Marks"]= data3["English"]+data3["Physics"]+data3["Chemistry"]+data3["Mathematics"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     238             # error: "None" not callable
# --> 239             return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     240     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     127     if result is None:
# --> 128         result = _evaluate_standard(op, op_str, a, b)
#     129
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
# ...

# %%
data3["English"]=data3["English"].astype(int)
data3["Chemistry"]=data3["Chemistry"].astype(int)
data3["Mathematics"]=data3["Mathematics"].astype(int)

# %%
data3["Total Marks"]= data3["English"]+data3["Physics"]+data3["Chemistry"]+data3["Mathematics"]

# %%
data3
# Out:
#   First Name    Last Name  English  Physics  Chemistry  Mathematics  \
# 0      Aarav        Patil       85       78         90           92
# 1     Vihaan     Deshmukh       88       81         85           89
# 2      Ayaan       Jadhav       90       75         88           84
# 3      Arjun         More       76       89         91           78
# 4    Reyansh        Joshi       82       80         84           85
# 5     Vivaan         Nair       87       83         79           90
# 6     Aditya        Pawar       92       88         76           91
# 7      Rohan  Suryavanshi       78       82         90           86
#
#    Total Marks
# 0          345
# 1          343
# 2          337
# 3          334
# 4          331
# 5          339
# 6          347
# 7          336
