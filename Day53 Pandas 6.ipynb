# %%
import pandas as pd

# %%
data2=pd.read_excel(r"C:\Ganesh\Minskole Python Batch\input data.xlsx")

# %% [markdown]
# ##

# %%
data2
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 0       Aarav     Patil       85       78         90           92
# 1      Vihaan  Deshmukh       88       81         85           89
# 2       Ayaan    Jadhav       90       75         88           84
# 3       Arjun      More       76       89         91           78
# 4     Reyansh     Joshi       82       80         84           85
# ..        ...       ...      ...      ...        ...          ...
# 60      Tarun    Dhumal       82       87         81           85
# 61      Arnav   Khedkar       85       90         78           89
# 62      Payal     Patil       89       76         87           91
# 63      Rahul     Kadam       81       83         84           90
# 64        Jay    Bhagat       90       77         65           88
#
# [65 rows x 6 columns]

# %%
# Filter data based on condition
data2["Physics"]>80
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4     False
#       ...
# 60     True
# 61     True
# 62    False
# 63     True
# 64    False
# Name: Physics, Length: 65, dtype: bool

# %%
data2[data2["Physics"]>80]
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics
# 1      Vihaan     Deshmukh       88       81         85           89
# 3       Arjun         More       76       89         91           78
# 5      Vivaan         Nair       87       83         79           90
# 6      Aditya        Pawar       92       88         76           91
# 7       Rohan  Suryavanshi       78       82         90           86
# 8       Krish      Bhosale       80       85         83           89
# 11     Vihaan     Deshmukh       88       81         85           89
# 13      Arjun         More       76       89         91           78
# 15     Vivaan         Nair       87       83         79           90
# 16     Aditya        Pawar       92       88         76           91
# 17      Rohan  Suryavanshi       78       82         90           86
# 18      Krish      Bhosale       80       85         83           89
# 20       Riya     Kulkarni       91       84         78           87
# ...

# %%
data2[data2["First Name"]=="Samarth"]
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics
# 9     Samarth    Shinde       89       79         87           88
# 19    Samarth    Shinde       89       79         87           88

# %%
data3=data2.copy()

# %%
data3["Total Marks"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Total Marks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
data3["Total Marks"]=data3["English"]+data3["Physics"]+data3["Chemistry"]+data3["Mathematics"]

# %%
data3
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  Total Marks
# 0       Aarav     Patil       85       78         90           92          345
# 1      Vihaan  Deshmukh       88       81         85           89          343
# 2       Ayaan    Jadhav       90       75         88           84          337
# 3       Arjun      More       76       89         91           78          334
# 4     Reyansh     Joshi       82       80         84           85          331
# ..        ...       ...      ...      ...        ...          ...          ...
# 60      Tarun    Dhumal       82       87         81           85          335
# 61      Arnav   Khedkar       85       90         78           89          342
# 62      Payal     Patil       89       76         87           91          343
# 63      Rahul     Kadam       81       83         84           90          338
# 64        Jay    Bhagat       90       77         65           88          320
#
# [65 rows x 7 columns]

# %%
#  Filter records whoes First name is Arjun and Tarun
data3["First Name"]="Arjun" & data3["First Name"]="Tarun"
# Out:
#   File "C:\Users\Prajakta\AppData\Local\Temp\ipykernel_20496\794258552.py", line 2
#     data3["First Name"]="Arjun" & data3["First Name"]="Tarun"
#                         ^
# SyntaxError: cannot assign to operator

# %%
data3[(data3['First Name'] =='Arjun') & (data3['First Name' ] =='Tarun')]
# Out:
# Empty DataFrame
# Columns: [First Name, Last Name, English, Physics, Chemistry, Mathematics, Total Marks]
# Index: []

# %%
# (data3['First Name'] =='Arjun') & (data3['First Name' ] =='Tarun')

# %%
data3[(data3['First Name'] =='Arjun') | (data3['First Name' ] =='Tarun')]
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  Total Marks
# 3       Arjun      More       76       89         91           78          334
# 13      Arjun      More       76       89         91           78          334
# 37      Tarun    Dhumal       82       87         81           85          335
# 60      Tarun    Dhumal       82       87         81           85          335

# %%
data3[data3["First Name"].isin(['Arjun','Tarun'])]
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  Total Marks
# 3       Arjun      More       76       89         91           78          334
# 13      Arjun      More       76       89         91           78          334
# 37      Tarun    Dhumal       82       87         81           85          335
# 60      Tarun    Dhumal       82       87         81           85          335

# %%
data3[(data3['First Name'].isin(['Arjun','Tarun']))] # First name is Arjun and Tarun
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  Total Marks
# 3       Arjun      More       76       89         91           78          334
# 13      Arjun      More       76       89         91           78          334
# 37      Tarun    Dhumal       82       87         81           85          335
# 60      Tarun    Dhumal       82       87         81           85          335

# %%
data3[~(data3['First Name'].isin(['Arjun','Tarun']))] # First name except Arjun and Tarun
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  Total Marks
# 0       Aarav     Patil       85       78         90           92          345
# 1      Vihaan  Deshmukh       88       81         85           89          343
# 2       Ayaan    Jadhav       90       75         88           84          337
# 4     Reyansh     Joshi       82       80         84           85          331
# 5      Vivaan      Nair       87       83         79           90          339
# ..        ...       ...      ...      ...        ...          ...          ...
# 59      Pooja    Mhatre       84       79         88           92          343
# 61      Arnav   Khedkar       85       90         78           89          342
# 62      Payal     Patil       89       76         87           91          343
# 63      Rahul     Kadam       81       83         84           90          338
# 64        Jay    Bhagat       90       77         65           88          320
#
# [61 rows x 7 columns]

# %%
data3
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  Total Marks
# 0       Aarav     Patil       85       78         90           92          345
# 1      Vihaan  Deshmukh       88       81         85           89          343
# 2       Ayaan    Jadhav       90       75         88           84          337
# 3       Arjun      More       76       89         91           78          334
# 4     Reyansh     Joshi       82       80         84           85          331
# ..        ...       ...      ...      ...        ...          ...          ...
# 60      Tarun    Dhumal       82       87         81           85          335
# 61      Arnav   Khedkar       85       90         78           89          342
# 62      Payal     Patil       89       76         87           91          343
# 63      Rahul     Kadam       81       83         84           90          338
# 64        Jay    Bhagat       90       77         65           88          320
#
# [65 rows x 7 columns]

# %%
data5["First Name"]=["Arjun","Tarun"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20496\3806509901.py in <module>
# ----> 1 data5["First Name"]=["Arjun","Tarun"]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# -> 4509             com.require_length_match(value, self.index)
# ...

# %%
data5=data3.copy()

# %%
# sort_values(by, ascending=True/False): Sorts the DataFrame by the specified column(s).

# %%
data3.head(2)
# Out:
#   First Name Last Name  English  Physics  Chemistry  Mathematics  Total Marks
# 0      Aarav     Patil       85       78         90           92          345
# 1     Vihaan  Deshmukh       88       81         85           89          343

# %%
data3.sort_values(by="Last Name",ascending=True)
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics  \
# 64        Jay       Bhagat       90       77         65           88
# 41       Jaya       Bhagat       92       88         76           89
# 56      Aarvi     Bhandari       90       81         85           91
# 33      Aarvi     Bhandari       90       81         85           91
# 8       Krish      Bhosale       80       85         83           89
# ..        ...          ...      ...      ...        ...          ...
# 9     Samarth       Shinde       89       79         87           88
# 17      Rohan  Suryavanshi       78       82         90           86
# 7       Rohan  Suryavanshi       78       82         90           86
# 24      Tejas     Waghmare       85       82         90           85
# 47      Tejas     Waghmare       85       82         90           85
#
#     Total Marks
# 64          320
# 41          345
# 56          347
# 33          347
# 8           337
# ..          ...
# ...

# %%
data4=data3.sort_values(by="Last Name",ascending=False)

# %%
data4
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics  \
# 47      Tejas     Waghmare       85       82         90           85
# 24      Tejas     Waghmare       85       82         90           85
# 7       Rohan  Suryavanshi       78       82         90           86
# 17      Rohan  Suryavanshi       78       82         90           86
# 9     Samarth       Shinde       89       79         87           88
# ..        ...          ...      ...      ...        ...          ...
# 18      Krish      Bhosale       80       85         83           89
# 56      Aarvi     Bhandari       90       81         85           91
# 33      Aarvi     Bhandari       90       81         85           91
# 41       Jaya       Bhagat       92       88         76           89
# 64        Jay       Bhagat       90       77         65           88
#
#     Total Marks
# 47          342
# 24          342
# 7           336
# 17          336
# 9           343
# ..          ...
# ...

# %%
data3.sort_values(by="Last Name",ascending=False,inplace=True) # inplace : True==> Change in original dataframe
                                                                #          False==> Changes not visible in original dataframe

# %%
data3
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics  \
# 47      Tejas     Waghmare       85       82         90           85
# 24      Tejas     Waghmare       85       82         90           85
# 7       Rohan  Suryavanshi       78       82         90           86
# 17      Rohan  Suryavanshi       78       82         90           86
# 9     Samarth       Shinde       89       79         87           88
# ..        ...          ...      ...      ...        ...          ...
# 18      Krish      Bhosale       80       85         83           89
# 56      Aarvi     Bhandari       90       81         85           91
# 33      Aarvi     Bhandari       90       81         85           91
# 41       Jaya       Bhagat       92       88         76           89
# 64        Jay       Bhagat       90       77         65           88
#
#     Total Marks
# 47          342
# 24          342
# 7           336
# 17          336
# 9           343
# ..          ...
# ...

# %%
data3.sort_values(by="Last Name",ascending=True).head()
# Out:
#    First Name Last Name  English  Physics  Chemistry  Mathematics  Total Marks
# 64        Jay    Bhagat       90       77         65           88          320
# 41       Jaya    Bhagat       92       88         76           89          345
# 56      Aarvi  Bhandari       90       81         85           91          347
# 33      Aarvi  Bhandari       90       81         85           91          347
# 18      Krish   Bhosale       80       85         83           89          337

# %%
data3.sort_values(by=["Last Name","Total Marks"],ascending=[True,False],inplace=True)

# %%
data3
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics  \
# 41       Jaya       Bhagat       92       88         76           89
# 64        Jay       Bhagat       90       77         65           88
# 56      Aarvi     Bhandari       90       81         85           91
# 33      Aarvi     Bhandari       90       81         85           91
# 8       Krish      Bhosale       80       85         83           89
# ..        ...          ...      ...      ...        ...          ...
# 19    Samarth       Shinde       89       79         87           88
# 7       Rohan  Suryavanshi       78       82         90           86
# 17      Rohan  Suryavanshi       78       82         90           86
# 47      Tejas     Waghmare       85       82         90           85
# 24      Tejas     Waghmare       85       82         90           85
#
#     Total Marks
# 41          345
# 64          320
# 56          347
# 33          347
# 8           337
# ..          ...
# ...

# %%
data4=data3.sort_values(by="Last Name",ascending=True)

# %%
data4
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics  \
# 41       Jaya       Bhagat       92       88         76           89
# 64        Jay       Bhagat       90       77         65           88
# 56      Aarvi     Bhandari       90       81         85           91
# 33      Aarvi     Bhandari       90       81         85           91
# 8       Krish      Bhosale       80       85         83           89
# ..        ...          ...      ...      ...        ...          ...
# 19    Samarth       Shinde       89       79         87           88
# 7       Rohan  Suryavanshi       78       82         90           86
# 17      Rohan  Suryavanshi       78       82         90           86
# 47      Tejas     Waghmare       85       82         90           85
# 24      Tejas     Waghmare       85       82         90           85
#
#     Total Marks
# 41          345
# 64          320
# 56          347
# 33          347
# 8           337
# ..          ...
# ...

# %%
data3.sort_values(by=["Last Name","Total Marks"],ascending=[True,False])
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics  \
# 41       Jaya       Bhagat       92       88         76           89
# 64        Jay       Bhagat       90       77         65           88
# 56      Aarvi     Bhandari       90       81         85           91
# 33      Aarvi     Bhandari       90       81         85           91
# 8       Krish      Bhosale       80       85         83           89
# ..        ...          ...      ...      ...        ...          ...
# 19    Samarth       Shinde       89       79         87           88
# 7       Rohan  Suryavanshi       78       82         90           86
# 17      Rohan  Suryavanshi       78       82         90           86
# 47      Tejas     Waghmare       85       82         90           85
# 24      Tejas     Waghmare       85       82         90           85
#
#     Total Marks
# 41          345
# 64          320
# 56          347
# 33          347
# 8           337
# ..          ...
# ...

# %%
data3
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics  \
# 41       Jaya       Bhagat       92       88         76           89
# 64        Jay       Bhagat       90       77         65           88
# 56      Aarvi     Bhandari       90       81         85           91
# 33      Aarvi     Bhandari       90       81         85           91
# 8       Krish      Bhosale       80       85         83           89
# ..        ...          ...      ...      ...        ...          ...
# 19    Samarth       Shinde       89       79         87           88
# 7       Rohan  Suryavanshi       78       82         90           86
# 17      Rohan  Suryavanshi       78       82         90           86
# 47      Tejas     Waghmare       85       82         90           85
# 24      Tejas     Waghmare       85       82         90           85
#
#     Total Marks
# 41          345
# 64          320
# 56          347
# 33          347
# 8           337
# ..          ...
# ...

# %%
data3.sort_values(by=["Last Name","Total Marks"],ascending=[True,False],inplace=True)

# %%
data3
# Out:
#    First Name    Last Name  English  Physics  Chemistry  Mathematics  \
# 41       Jaya       Bhagat       92       88         76           89
# 64        Jay       Bhagat       90       77         65           88
# 56      Aarvi     Bhandari       90       81         85           91
# 33      Aarvi     Bhandari       90       81         85           91
# 8       Krish      Bhosale       80       85         83           89
# ..        ...          ...      ...      ...        ...          ...
# 19    Samarth       Shinde       89       79         87           88
# 7       Rohan  Suryavanshi       78       82         90           86
# 17      Rohan  Suryavanshi       78       82         90           86
# 47      Tejas     Waghmare       85       82         90           85
# 24      Tejas     Waghmare       85       82         90           85
#
#     Total Marks
# 41          345
# 64          320
# 56          347
# 33          347
# 8           337
# ..          ...
# ...
